# %%
# !mkdir -p ~/models/flair
# !cd ~/models/flair

# %%
import torch

state = torch.load("/home/pavel/ITMO/NIR2/FLAIR-INC_rgbie_15cl_resnet34-unet/weights.pth", map_location="cpu")
model = state["model"]
model.eval()
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[13], line 2
#       1 import torch
# ----> 2 state = torch.load("/home/pavel/ITMO/NIR2/FLAIR-INC_rgbie_15cl_resnet34-unet/FLAIR-INC_rgbie_15cl_resnet34-unet_weights.pth", map_location="cpu", weights_only=False)
#       3 print(type(state))
#
# File ~/anaconda3/envs/flair/lib/python3.10/site-packages/torch/serialization.py:1554, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1552     except pickle.UnpicklingError as e:
#    1553         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1554 return _legacy_load(
#    1555     opened_file, map_location, pickle_module, **pickle_load_args
#    1556 )
#
# File ~/anaconda3/envs/flair/lib/python3.10/site-packages/torch/serialization.py:1802, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
# ...

# %%
from flair.models import SegmentationModel
model = SegmentationModel.from_pretrained("IGNF/FLAIR-INC_rgb_15cl_resnet34-fpn")
print(model)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from flair.models import SegmentationModel
#       2 model = SegmentationModel.from_pretrained("IGNF/FLAIR-INC_rgb_15cl_resnet34-fpn")
#       3 print(model)
#
# ModuleNotFoundError: No module named 'flair'
